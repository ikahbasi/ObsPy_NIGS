# %% [markdown]
# ![IGS-logo-ftr-cntr-300x300.png](attachment:IGS-logo-ftr-cntr-300x300.png)
# <h1><center>Iman Kahbasi</center></h1>
# <h1><center>PhD student at IIEES</center></h1>
# <h1><center>Beachball Plot</center></h1>
# <h1><center>1400-12-18</center></h1>

# %% [markdown]
# # Six independent components of the moment tensor

# %%
from obspy.imaging.beachball import beachball


mt = [0.91, -0.89, -0.02, 1.78, -1.55, 0.47]
beachball(mt, size=200, linewidth=2, facecolor='b')
print()

# %%
mt2 = [150, 87, 1]
beachball(mt2, size=200, linewidth=2, facecolor='r')
print()

# %%
mt3 = [-2.39, 1.04, 1.35, 0.57, -2.94, -0.94]
beachball(mt3, size=200, linewidth=2, facecolor='g')
print()

# %% [markdown]
# # strike, dip, and rake

# %%
mt4 = [0, 90, 0]
beachball(mt4, facecolor='g')
print()

# %% [markdown]
# # Function
# https://docs.obspy.org/packages/autogen/obspy.imaging.mopad_wrapper.beachball.html

# %%
mt = [1, 2, 3, -4, -5, -10]

beachball(mt, linewidth=2,
          facecolor='b', bgcolor='w', edgecolor='k', alpha=1.0,
          xy=(0, 0), width=200, size=100,
          nofill=False, zorder=100,
          outfile=None, format=None, fig=None)
