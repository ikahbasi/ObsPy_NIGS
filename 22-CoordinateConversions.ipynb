# %% [markdown]
# ![IGS-logo-ftr-cntr-300x300.png](attachment:IGS-logo-ftr-cntr-300x300.png)
# <h1><center>Iman Kahbasi</center></h1>
# <h1><center>PhD student at IIEES</center></h1>
# <h1><center>Beachball Plot</center></h1>
# <h1><center>1400-12-18</center></h1>

# %% [markdown]
# https://docs.obspy.org/tutorial/code_snippets/coordinate_conversions.html
#
# https://github.com/Turbo87/utm

# %%
import utm

# %%
easting, northing, zone_number, zone_letter = utm.from_latlon(latitude=51.2, longitude= 7.5)

# %%
lat, lon = utm.to_latlon(easting=340000, northing=5710000, zone_number=32, zone_letter='U')
